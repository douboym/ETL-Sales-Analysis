# %%
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker
from sqlalchemy.types import Text, Float, Integer, Date

# 🔹 1️⃣ Charger les données avec le bon encodage
file_path = "C:/Users/HP/OneDrive/.kaggle/data/sales_100k.csv"

try:
    df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='latin1')

# 🔹 2️⃣ Supprimer les colonnes inutiles (ignorer si elles n'existent pas)
df.drop(columns=['Unnamed: 0', 'Sales_ID'], inplace=True, errors='ignore')

# 🔹 3️⃣ Nettoyer les valeurs manquantes
df = df.assign(
    Sales_Amount=df['Sales_Amount'].fillna(df['Sales_Amount'].mean()),
    Discount=df['Discount'].fillna(0),
    Customer_Age=df['Customer_Age'].fillna(df['Customer_Age'].median()),
    Customer_Gender=df['Customer_Gender'].fillna("Unknown")
)

# 🔹 4️⃣ Convertir Date_of_Sale en format date
df['Date_of_Sale'] = pd.to_datetime(df['Date_of_Sale'], errors='coerce')

# 🔹 5️⃣ Convertir Customer_Age en entier
df['Customer_Age'] = df['Customer_Age'].astype('Int64')  # Supporte les NaN

# 🔹 6️⃣ Vérifier et forcer l'encodage UTF-8 sur les colonnes textuelles
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype(str).apply(lambda x: x.encode('utf-8', errors='ignore').decode('utf-8'))

# 🔹 7️⃣ Connexion à PostgreSQL avec gestion des transactions
DB_USER = "postgres"  
DB_PASSWORD = "868011"  # 🔥 Remplace par ton mot de passe PostgreSQL
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "ventes"

from sqlalchemy import create_engine, text

# 🔹 Connexion PostgreSQL avec autocommit activé
engine = create_engine(f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}', isolation_level="AUTOCOMMIT", echo=True)  # 🔹 Mode debug activé

with engine.connect() as connection:
    try:
        # 🔹 Supprimer la table avant d'insérer
        connection.execute(text("DROP TABLE IF EXISTS ventes_data;"))

        # 🔹 Insérer les données dans PostgreSQL
        df.to_sql('ventes_data', connection, if_exists='replace', index=False, dtype={
            "Product_Category": Text,
            "Sales_Amount": Float,
            "Discount": Float,
            "Sales_Region": Text,
            "Date_of_Sale": Date,
            "Customer_Age": Integer,
            "Customer_Gender": Text,
            "Sales_Representative": Text
        }, chunksize=5000)  # 🔹 Insertion par paquets de 5000 lignes

        print(f"\n✅ {len(df)} lignes insérées avec succès dans PostgreSQL !")

    except Exception as e:
        print("\n❌ Erreur lors de l'insertion :", e)
# Out:
# 2025-02-16 00:17:23,387 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-02-16 00:17:23,395 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-16 00:17:23,406 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-02-16 00:17:23,407 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-16 00:17:23,411 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-02-16 00:17:23,413 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-16 00:17:23,424 INFO sqlalchemy.engine.Engine BEGIN (implicit; DBAPI should not BEGIN due to autocommit mode)
# 2025-02-16 00:17:23,426 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS ventes_data;
# 2025-02-16 00:17:23,428 INFO sqlalchemy.engine.Engine [generated in 0.00499s] {}
# 2025-02-16 00:17:23,504 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-02-16 00:17:23,505 INFO sqlalchemy.engine.Engine [generated in 0.00153s] {'table_name': 'ventes_data', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-02-16 00:17:23,520 INFO sqlalchemy.engine.Engine
# CREATE TABLE ventes_data (
# 	"Product_Category" TEXT,
# 	"Sales_Amount" FLOAT,
# 	"Discount" FLOAT,
# 	"Sales_Region" TEXT,
# 	"Date_of_Sale" DATE,
# 	"Customer_Age" INTEGER,
# 	"Customer_Gender" TEXT,
# 	"Sales_Representative" TEXT
# )
#
#
# 2025-02-16 00:17:23,521 INFO sqlalchemy.engine.Engine [no key 0.00100s] {}
# 2025-02-16 00:17:23,797 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:23,800 INFO sqlalchemy.engine.Engine [generated in 0.05890s (insertmanyvalues) 1/5 (unordered)] {'Sales_Region__0': 'East Dianeport', 'Discount__0': 45.98, 'Customer_Gender__0': 'Male', 'Product_Category__0': 'Movies', 'Date_of_Sale__0': datetime.datetime(2024, 7, 12, 0, 0), 'Sales_Amount__0': 341.05, 'Sales_Representative__0': 'Bruce Rodriguez', 'Customer_Age__0': 69, 'Sales_Region__1': 'North Linda', 'Discount__1': 29.59, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Pet Supplies', 'Date_of_Sale__1': datetime.datetime(2024, 5, 7, 0, 0), 'Sales_Amount__1': 594.71, 'Sales_Representative__1': 'Patricia Pugh', 'Customer_Age__1': 32, 'Sales_Region__2': 'Lake Josephmouth', 'Discount__2': 49.78, 'Customer_Gender__2': 'Other', 'Product_Category__2': 'Outdoor', 'Date_of_Sale__2': datetime.datetime(2024, 5, 11, 0, 0), 'Sales_Amount__2': 351.9, 'Sales_Representative__2': 'Kevin Fuentes', 'Customer_Age__2': 28, 'Sales_Region__3': 'North Martinside', 'Discount__3': 0.0, 'Customer_Gender__3': 'Unknown', 'Product_Category__3': 'Electronics', 'Date_of_Sale__3': datetime.datetime(2024, 9, 2, 0, 0), 'Sales_Amount__3': 550.1708058888889, 'Sales_Representative__3': 'Evelyn Price', 'Customer_Age__3': 44, 'Sales_Region__4': 'Michealshire', 'Discount__4': 27.21, 'Customer_Gender__4': 'Other', 'Product_Category__4': 'Books', 'Date_of_Sale__4': datetime.datetime(2024, 5, 2, 0, 0), 'Sales_Amount__4': 795.75, 'Sales_Representative__4': 'Joseph Chavez', 'Customer_Age__4': 21, 'Sales_Region__5': 'Joelmouth', 'Discount__5': 28.54, 'Customer_Gender__5': 'Female', 'Product_Category__5': 'Books', 'Date_of_Sale__5': datetime.datetime(2024, 1, 2, 0, 0), 'Sales_Amount__5': 526.17, 'Sales_Representative__5': 'Tyler Graves', 'Customer_Age__5': 61, 'Sales_Region__6': 'Lake Ericashire', 'Discount__6': 0.27 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Michael Lane', 'Customer_Age__993': 49, 'Sales_Region__994': 'Banksberg', 'Discount__994': 33.46, 'Customer_Gender__994': 'Other', 'Product_Category__994': 'Appliances', 'Date_of_Sale__994': datetime.datetime(2024, 4, 1, 0, 0), 'Sales_Amount__994': 726.31, 'Sales_Representative__994': 'Sarah Stewart', 'Customer_Age__994': 37, 'Sales_Region__995': 'Kirbymouth', 'Discount__995': 7.63, 'Customer_Gender__995': 'Male', 'Product_Category__995': 'Pet Supplies', 'Date_of_Sale__995': datetime.datetime(2024, 6, 22, 0, 0), 'Sales_Amount__995': 384.54, 'Sales_Representative__995': 'Patricia Mosley', 'Customer_Age__995': 35, 'Sales_Region__996': 'Anneshire', 'Discount__996': 33.69, 'Customer_Gender__996': 'Other', 'Product_Category__996': 'Personal Care', 'Date_of_Sale__996': datetime.datetime(2024, 7, 8, 0, 0), 'Sales_Amount__996': 558.16, 'Sales_Representative__996': 'Toni Patton', 'Customer_Age__996': 45, 'Sales_Region__997': 'West Jamesberg', 'Discount__997': 0.0, 'Customer_Gender__997': 'Unknown', 'Product_Category__997': 'Groceries', 'Date_of_Sale__997': datetime.datetime(2024, 2, 25, 0, 0), 'Sales_Amount__997': 550.1708058888889, 'Sales_Representative__997': 'Brenda Nielsen', 'Customer_Age__997': 44, 'Sales_Region__998': 'Matthewview', 'Discount__998': 0.0, 'Customer_Gender__998': 'Unknown', 'Product_Category__998': 'Office Supplies', 'Date_of_Sale__998': datetime.datetime(2024, 5, 16, 0, 0), 'Sales_Amount__998': 550.1708058888889, 'Sales_Representative__998': 'Heidi Alvarez', 'Customer_Age__998': 44, 'Sales_Region__999': 'Port Dominique', 'Discount__999': 16.67, 'Customer_Gender__999': 'Male', 'Product_Category__999': 'Tools', 'Date_of_Sale__999': datetime.datetime(2024, 6, 27, 0, 0), 'Sales_Amount__999': 491.18, 'Sales_Representative__999': 'Megan Stephens', 'Customer_Age__999': 63}
# 2025-02-16 00:17:23,903 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:23,904 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/5 (unordered)] {'Sales_Region__0': 'Port Daniel', 'Discount__0': 18.36, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Toys', 'Date_of_Sale__0': datetime.datetime(2024, 2, 28, 0, 0), 'Sales_Amount__0': 531.6, 'Sales_Representative__0': 'Cassandra Wallace', 'Customer_Age__0': 36, 'Sales_Region__1': 'North Tyler', 'Discount__1': 37.22, 'Customer_Gender__1': 'Male', 'Product_Category__1': 'Appliances', 'Date_of_Sale__1': datetime.datetime(2024, 2, 1, 0, 0), 'Sales_Amount__1': 698.8, 'Sales_Representative__1': 'Joshua Lawson', 'Customer_Age__1': 19, 'Sales_Region__2': 'Whiteland', 'Discount__2': 31.5, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Home & Kitchen', 'Date_of_Sale__2': datetime.datetime(2024, 4, 15, 0, 0), 'Sales_Amount__2': 263.0, 'Sales_Representative__2': 'Jeanette Norton', 'Customer_Age__2': 46, 'Sales_Region__3': 'South Mercedes', 'Discount__3': 25.62, 'Customer_Gender__3': 'Other', 'Product_Category__3': 'DIY', 'Date_of_Sale__3': datetime.datetime(2024, 4, 12, 0, 0), 'Sales_Amount__3': 946.81, 'Sales_Representative__3': 'Veronica Cruz', 'Customer_Age__3': 56, 'Sales_Region__4': 'Lisabury', 'Discount__4': 0.0, 'Customer_Gender__4': 'Unknown', 'Product_Category__4': 'Books', 'Date_of_Sale__4': datetime.datetime(2024, 4, 3, 0, 0), 'Sales_Amount__4': 550.1708058888889, 'Sales_Representative__4': 'Douglas Montgomery', 'Customer_Age__4': 44, 'Sales_Region__5': 'Hernandezberg', 'Discount__5': 42.27, 'Customer_Gender__5': 'Other', 'Product_Category__5': 'Music', 'Date_of_Sale__5': datetime.datetime(2024, 3, 16, 0, 0), 'Sales_Amount__5': 377.53, 'Sales_Representative__5': 'Brian Harris', 'Customer_Age__5': 67, 'Sales_Region__6': 'Port Luke', 'Discount__6': 3.11 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Christopher Carter', 'Customer_Age__993': 36, 'Sales_Region__994': 'Thomaston', 'Discount__994': 0.0, 'Customer_Gender__994': 'Unknown', 'Product_Category__994': 'Clothing', 'Date_of_Sale__994': datetime.datetime(2024, 5, 26, 0, 0), 'Sales_Amount__994': 550.1708058888889, 'Sales_Representative__994': 'Kyle Adams', 'Customer_Age__994': 44, 'Sales_Region__995': 'North David', 'Discount__995': 24.59, 'Customer_Gender__995': 'Female', 'Product_Category__995': 'Movies', 'Date_of_Sale__995': datetime.datetime(2024, 3, 16, 0, 0), 'Sales_Amount__995': 695.25, 'Sales_Representative__995': 'Ronald Aguilar', 'Customer_Age__995': 44, 'Sales_Region__996': 'Loweburgh', 'Discount__996': 27.01, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Office Supplies', 'Date_of_Sale__996': datetime.datetime(2024, 9, 5, 0, 0), 'Sales_Amount__996': 862.64, 'Sales_Representative__996': 'Melissa Fields', 'Customer_Age__996': 44, 'Sales_Region__997': 'North Williamshire', 'Discount__997': 10.0, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'DIY', 'Date_of_Sale__997': datetime.datetime(2024, 3, 1, 0, 0), 'Sales_Amount__997': 285.67, 'Sales_Representative__997': 'Michael Flores', 'Customer_Age__997': 36, 'Sales_Region__998': 'North Jon', 'Discount__998': 11.62, 'Customer_Gender__998': 'Other', 'Product_Category__998': 'Jewelry', 'Date_of_Sale__998': datetime.datetime(2024, 4, 11, 0, 0), 'Sales_Amount__998': 895.55, 'Sales_Representative__998': 'Robert Gardner', 'Customer_Age__998': 34, 'Sales_Region__999': 'New Vanessaport', 'Discount__999': 46.22, 'Customer_Gender__999': 'Female', 'Product_Category__999': 'Books', 'Date_of_Sale__999': datetime.datetime(2024, 2, 10, 0, 0), 'Sales_Amount__999': 622.62, 'Sales_Representative__999': 'Renee Love', 'Customer_Age__999': 48}
# 2025-02-16 00:17:23,997 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:23,998 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/5 (unordered)] {'Sales_Region__0': 'Port Lonnieberg', 'Discount__0': 10.38, 'Customer_Gender__0': 'Male', 'Product_Category__0': 'Office Supplies', 'Date_of_Sale__0': datetime.datetime(2024, 8, 20, 0, 0), 'Sales_Amount__0': 675.0, 'Sales_Representative__0': 'Lisa Fuentes', 'Customer_Age__0': 26, 'Sales_Region__1': 'Port Frank', 'Discount__1': 4.97, 'Customer_Gender__1': 'Female', 'Product_Category__1': 'Tools', 'Date_of_Sale__1': datetime.datetime(2024, 2, 5, 0, 0), 'Sales_Amount__1': 553.12, 'Sales_Representative__1': 'Robert Whitney', 'Customer_Age__1': 42, 'Sales_Region__2': 'Douglastown', 'Discount__2': 21.32, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Garden', 'Date_of_Sale__2': datetime.datetime(2024, 8, 7, 0, 0), 'Sales_Amount__2': 485.11, 'Sales_Representative__2': 'Kyle French', 'Customer_Age__2': 60, 'Sales_Region__3': 'New Morgan', 'Discount__3': 0.0, 'Customer_Gender__3': 'Unknown', 'Product_Category__3': 'Personal Care', 'Date_of_Sale__3': datetime.datetime(2024, 7, 28, 0, 0), 'Sales_Amount__3': 550.1708058888889, 'Sales_Representative__3': 'James Arnold', 'Customer_Age__3': 44, 'Sales_Region__4': 'Lake Jessica', 'Discount__4': 0.0, 'Customer_Gender__4': 'Unknown', 'Product_Category__4': 'Tools', 'Date_of_Sale__4': datetime.datetime(2024, 4, 11, 0, 0), 'Sales_Amount__4': 550.1708058888889, 'Sales_Representative__4': 'Rachel Hernandez', 'Customer_Age__4': 44, 'Sales_Region__5': 'Fordchester', 'Discount__5': 32.95, 'Customer_Gender__5': 'Female', 'Product_Category__5': 'Garden', 'Date_of_Sale__5': datetime.datetime(2024, 3, 5, 0, 0), 'Sales_Amount__5': 634.22, 'Sales_Representative__5': 'Adam George', 'Customer_Age__5': 69, 'Sales_Region__6': 'Jenkinsstad', 'Discount__6': 11.19 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Michael Carter', 'Customer_Age__993': 41, 'Sales_Region__994': 'West Laurie', 'Discount__994': 0.0, 'Customer_Gender__994': 'Unknown', 'Product_Category__994': 'Jewelry', 'Date_of_Sale__994': datetime.datetime(2024, 7, 10, 0, 0), 'Sales_Amount__994': 550.1708058888889, 'Sales_Representative__994': 'Lonnie Evans', 'Customer_Age__994': 44, 'Sales_Region__995': 'East Stacy', 'Discount__995': 1.97, 'Customer_Gender__995': 'Other', 'Product_Category__995': 'Pet Supplies', 'Date_of_Sale__995': datetime.datetime(2024, 1, 22, 0, 0), 'Sales_Amount__995': 998.16, 'Sales_Representative__995': 'Michelle Norris', 'Customer_Age__995': 47, 'Sales_Region__996': 'Fletcherhaven', 'Discount__996': 39.04, 'Customer_Gender__996': 'Other', 'Product_Category__996': 'Outdoor', 'Date_of_Sale__996': datetime.datetime(2024, 7, 7, 0, 0), 'Sales_Amount__996': 806.38, 'Sales_Representative__996': 'Dr. Ryan Castillo MD', 'Customer_Age__996': 65, 'Sales_Region__997': 'North Jermaine', 'Discount__997': 45.83, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Toys', 'Date_of_Sale__997': datetime.datetime(2024, 4, 15, 0, 0), 'Sales_Amount__997': 754.8, 'Sales_Representative__997': 'Christopher Spencer', 'Customer_Age__997': 24, 'Sales_Region__998': 'Williamsmouth', 'Discount__998': 23.87, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Appliances', 'Date_of_Sale__998': datetime.datetime(2024, 8, 11, 0, 0), 'Sales_Amount__998': 560.88, 'Sales_Representative__998': 'Rachel Williams', 'Customer_Age__998': 65, 'Sales_Region__999': 'South Deborahview', 'Discount__999': 43.5, 'Customer_Gender__999': 'Female', 'Product_Category__999': 'Movies', 'Date_of_Sale__999': datetime.datetime(2024, 7, 5, 0, 0), 'Sales_Amount__999': 658.07, 'Sales_Representative__999': 'Craig Dixon', 'Customer_Age__999': 20}
# 2025-02-16 00:17:24,097 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,098 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/5 (unordered)] {'Sales_Region__0': 'South Jesse', 'Discount__0': 21.76, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Movies', 'Date_of_Sale__0': datetime.datetime(2024, 9, 2, 0, 0), 'Sales_Amount__0': 121.57, 'Sales_Representative__0': 'Brandy Taylor', 'Customer_Age__0': 33, 'Sales_Region__1': 'Shafferville', 'Discount__1': 37.42, 'Customer_Gender__1': 'Female', 'Product_Category__1': 'Furniture', 'Date_of_Sale__1': datetime.datetime(2024, 3, 9, 0, 0), 'Sales_Amount__1': 798.88, 'Sales_Representative__1': 'Justin Gibson', 'Customer_Age__1': 55, 'Sales_Region__2': 'Sanchezville', 'Discount__2': 16.5, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Home & Kitchen', 'Date_of_Sale__2': datetime.datetime(2024, 8, 6, 0, 0), 'Sales_Amount__2': 198.88, 'Sales_Representative__2': 'Thomas Roberts', 'Customer_Age__2': 20, 'Sales_Region__3': 'North William', 'Discount__3': 8.5, 'Customer_Gender__3': 'Other', 'Product_Category__3': 'Sports', 'Date_of_Sale__3': datetime.datetime(2024, 2, 4, 0, 0), 'Sales_Amount__3': 611.6, 'Sales_Representative__3': 'Cheryl Thompson', 'Customer_Age__3': 47, 'Sales_Region__4': 'Anthonyview', 'Discount__4': 16.26, 'Customer_Gender__4': 'Male', 'Product_Category__4': 'Personal Care', 'Date_of_Sale__4': datetime.datetime(2024, 3, 14, 0, 0), 'Sales_Amount__4': 168.97, 'Sales_Representative__4': 'Breanna White', 'Customer_Age__4': 44, 'Sales_Region__5': 'South Janeport', 'Discount__5': 0.0, 'Customer_Gender__5': 'Unknown', 'Product_Category__5': 'Home & Kitchen', 'Date_of_Sale__5': datetime.datetime(2024, 1, 28, 0, 0), 'Sales_Amount__5': 550.1708058888889, 'Sales_Representative__5': 'Jamie Jennings', 'Customer_Age__5': 44, 'Sales_Region__6': 'Jamesville', 'Discount__6': 22.69 ... 7900 parameters truncated ... 'Sales_Representative__993': 'David Ward', 'Customer_Age__993': 49, 'Sales_Region__994': 'Lake Nicholas', 'Discount__994': 0.0, 'Customer_Gender__994': 'Unknown', 'Product_Category__994': 'Automotive', 'Date_of_Sale__994': datetime.datetime(2024, 7, 7, 0, 0), 'Sales_Amount__994': 550.1708058888889, 'Sales_Representative__994': 'Richard King', 'Customer_Age__994': 44, 'Sales_Region__995': 'West Michael', 'Discount__995': 0.0, 'Customer_Gender__995': 'Unknown', 'Product_Category__995': 'Tools', 'Date_of_Sale__995': datetime.datetime(2024, 5, 1, 0, 0), 'Sales_Amount__995': 550.1708058888889, 'Sales_Representative__995': 'Makayla Garcia', 'Customer_Age__995': 44, 'Sales_Region__996': 'New Jerrychester', 'Discount__996': 0.0, 'Customer_Gender__996': 'Unknown', 'Product_Category__996': 'Electronics', 'Date_of_Sale__996': datetime.datetime(2024, 9, 4, 0, 0), 'Sales_Amount__996': 550.1708058888889, 'Sales_Representative__996': 'Kathleen Watson', 'Customer_Age__996': 44, 'Sales_Region__997': 'Griffinhaven', 'Discount__997': 24.38, 'Customer_Gender__997': 'Other', 'Product_Category__997': 'Office Supplies', 'Date_of_Sale__997': datetime.datetime(2024, 6, 26, 0, 0), 'Sales_Amount__997': 701.96, 'Sales_Representative__997': 'April Joseph', 'Customer_Age__997': 49, 'Sales_Region__998': 'West Tyler', 'Discount__998': 40.12, 'Customer_Gender__998': 'Female', 'Product_Category__998': 'Jewelry', 'Date_of_Sale__998': datetime.datetime(2024, 5, 1, 0, 0), 'Sales_Amount__998': 233.26, 'Sales_Representative__998': 'Kevin Mckenzie', 'Customer_Age__998': 31, 'Sales_Region__999': 'Valerieland', 'Discount__999': 33.24, 'Customer_Gender__999': 'Female', 'Product_Category__999': 'Movies', 'Date_of_Sale__999': datetime.datetime(2024, 2, 4, 0, 0), 'Sales_Amount__999': 848.19, 'Sales_Representative__999': 'Shannon Kirby', 'Customer_Age__999': 63}
# 2025-02-16 00:17:24,190 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,192 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/5 (unordered)] {'Sales_Region__0': 'Vegastad', 'Discount__0': 9.11, 'Customer_Gender__0': 'Other', 'Product_Category__0': 'Personal Care', 'Date_of_Sale__0': datetime.datetime(2024, 4, 16, 0, 0), 'Sales_Amount__0': 776.98, 'Sales_Representative__0': 'Kevin Gill', 'Customer_Age__0': 69, 'Sales_Region__1': 'Port Matthewport', 'Discount__1': 31.92, 'Customer_Gender__1': 'Male', 'Product_Category__1': 'Appliances', 'Date_of_Sale__1': datetime.datetime(2024, 8, 15, 0, 0), 'Sales_Amount__1': 443.97, 'Sales_Representative__1': 'Curtis Anderson', 'Customer_Age__1': 25, 'Sales_Region__2': 'Lake Regina', 'Discount__2': 38.03, 'Customer_Gender__2': 'Female', 'Product_Category__2': 'Toys', 'Date_of_Sale__2': datetime.datetime(2024, 5, 10, 0, 0), 'Sales_Amount__2': 408.1, 'Sales_Representative__2': 'Chad Cantu', 'Customer_Age__2': 32, 'Sales_Region__3': 'Kochshire', 'Discount__3': 0.0, 'Customer_Gender__3': 'Unknown', 'Product_Category__3': 'Office Supplies', 'Date_of_Sale__3': datetime.datetime(2024, 7, 16, 0, 0), 'Sales_Amount__3': 550.1708058888889, 'Sales_Representative__3': 'Michael Atkinson', 'Customer_Age__3': 44, 'Sales_Region__4': 'Caitlinburgh', 'Discount__4': 4.94, 'Customer_Gender__4': 'Male', 'Product_Category__4': 'Pet Supplies', 'Date_of_Sale__4': datetime.datetime(2024, 2, 12, 0, 0), 'Sales_Amount__4': 970.29, 'Sales_Representative__4': 'Latoya Avila', 'Customer_Age__4': 63, 'Sales_Region__5': 'Patrickburgh', 'Discount__5': 16.59, 'Customer_Gender__5': 'Other', 'Product_Category__5': 'Sports', 'Date_of_Sale__5': datetime.datetime(2024, 1, 6, 0, 0), 'Sales_Amount__5': 497.35, 'Sales_Representative__5': 'Lisa Brown', 'Customer_Age__5': 18, 'Sales_Region__6': 'South William', 'Discount__6': 5.11 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Edward Wolf', 'Customer_Age__993': 23, 'Sales_Region__994': 'Port Ana', 'Discount__994': 31.49, 'Customer_Gender__994': 'Male', 'Product_Category__994': 'Electronics', 'Date_of_Sale__994': datetime.datetime(2024, 1, 3, 0, 0), 'Sales_Amount__994': 309.06, 'Sales_Representative__994': 'Desiree Smith', 'Customer_Age__994': 49, 'Sales_Region__995': 'Adamborough', 'Discount__995': 1.18, 'Customer_Gender__995': 'Other', 'Product_Category__995': 'Toys', 'Date_of_Sale__995': datetime.datetime(2024, 5, 16, 0, 0), 'Sales_Amount__995': 474.1, 'Sales_Representative__995': 'Elizabeth Scott', 'Customer_Age__995': 32, 'Sales_Region__996': 'Martinchester', 'Discount__996': 49.2, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Personal Care', 'Date_of_Sale__996': datetime.datetime(2024, 8, 21, 0, 0), 'Sales_Amount__996': 550.08, 'Sales_Representative__996': 'Jason Holmes', 'Customer_Age__996': 23, 'Sales_Region__997': 'West Samantha', 'Discount__997': 0.0, 'Customer_Gender__997': 'Unknown', 'Product_Category__997': 'Health', 'Date_of_Sale__997': datetime.datetime(2024, 2, 10, 0, 0), 'Sales_Amount__997': 550.1708058888889, 'Sales_Representative__997': 'Michael Morales', 'Customer_Age__997': 44, 'Sales_Region__998': 'West Katiehaven', 'Discount__998': 1.53, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Tools', 'Date_of_Sale__998': datetime.datetime(2024, 7, 18, 0, 0), 'Sales_Amount__998': 870.46, 'Sales_Representative__998': 'Matthew James', 'Customer_Age__998': 22, 'Sales_Region__999': 'Kristenmouth', 'Discount__999': 26.45, 'Customer_Gender__999': 'Male', 'Product_Category__999': 'Garden', 'Date_of_Sale__999': datetime.datetime(2024, 7, 27, 0, 0), 'Sales_Amount__999': 915.08, 'Sales_Representative__999': 'Jonathan Jensen', 'Customer_Age__999': 65}
# 2025-02-16 00:17:24,368 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,369 INFO sqlalchemy.engine.Engine [cached since 0.627s ago (insertmanyvalues) 1/5 (unordered)] {'Sales_Region__0': 'Robertsonfurt', 'Discount__0': 15.54, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Movies', 'Date_of_Sale__0': datetime.datetime(2024, 5, 15, 0, 0), 'Sales_Amount__0': 845.9, 'Sales_Representative__0': 'Shane Cohen', 'Customer_Age__0': 48, 'Sales_Region__1': 'Samuelmouth', 'Discount__1': 33.59, 'Customer_Gender__1': 'Male', 'Product_Category__1': 'Outdoor', 'Date_of_Sale__1': datetime.datetime(2024, 1, 4, 0, 0), 'Sales_Amount__1': 527.35, 'Sales_Representative__1': 'Jillian Mendoza', 'Customer_Age__1': 19, 'Sales_Region__2': 'New Joseph', 'Discount__2': 14.64, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Beauty', 'Date_of_Sale__2': datetime.datetime(2024, 5, 1, 0, 0), 'Sales_Amount__2': 438.41, 'Sales_Representative__2': 'Virginia Rice', 'Customer_Age__2': 49, 'Sales_Region__3': 'Hillshire', 'Discount__3': 16.47, 'Customer_Gender__3': 'Male', 'Product_Category__3': 'Home & Kitchen', 'Date_of_Sale__3': datetime.datetime(2024, 5, 20, 0, 0), 'Sales_Amount__3': 737.58, 'Sales_Representative__3': 'Lynn Reynolds', 'Customer_Age__3': 22, 'Sales_Region__4': 'Walkerborough', 'Discount__4': 2.43, 'Customer_Gender__4': 'Other', 'Product_Category__4': 'Jewelry', 'Date_of_Sale__4': datetime.datetime(2024, 2, 12, 0, 0), 'Sales_Amount__4': 726.75, 'Sales_Representative__4': 'Sheila Rhodes', 'Customer_Age__4': 61, 'Sales_Region__5': 'North Marcburgh', 'Discount__5': 0.0, 'Customer_Gender__5': 'Unknown', 'Product_Category__5': 'Movies', 'Date_of_Sale__5': datetime.datetime(2024, 3, 12, 0, 0), 'Sales_Amount__5': 550.1708058888889, 'Sales_Representative__5': 'Karen Castillo', 'Customer_Age__5': 44, 'Sales_Region__6': 'Annamouth', 'Discount__6': 36.89 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Heather Wells', 'Customer_Age__993': 64, 'Sales_Region__994': 'North Jamie', 'Discount__994': 12.74, 'Customer_Gender__994': 'Male', 'Product_Category__994': 'Automotive', 'Date_of_Sale__994': datetime.datetime(2024, 6, 24, 0, 0), 'Sales_Amount__994': 577.34, 'Sales_Representative__994': 'Samantha Green', 'Customer_Age__994': 19, 'Sales_Region__995': 'Brownport', 'Discount__995': 32.92, 'Customer_Gender__995': 'Male', 'Product_Category__995': 'Movies', 'Date_of_Sale__995': datetime.datetime(2024, 1, 29, 0, 0), 'Sales_Amount__995': 793.4, 'Sales_Representative__995': 'Sara Price', 'Customer_Age__995': 68, 'Sales_Region__996': 'Leefort', 'Discount__996': 41.11, 'Customer_Gender__996': 'Other', 'Product_Category__996': 'Tools', 'Date_of_Sale__996': datetime.datetime(2024, 2, 21, 0, 0), 'Sales_Amount__996': 705.37, 'Sales_Representative__996': 'Hannah Knox', 'Customer_Age__996': 18, 'Sales_Region__997': 'Benjaminton', 'Discount__997': 35.94, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Beauty', 'Date_of_Sale__997': datetime.datetime(2024, 1, 14, 0, 0), 'Sales_Amount__997': 200.94, 'Sales_Representative__997': 'Raymond Watkins', 'Customer_Age__997': 52, 'Sales_Region__998': 'Sanchezville', 'Discount__998': 3.2, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Home & Kitchen', 'Date_of_Sale__998': datetime.datetime(2024, 6, 18, 0, 0), 'Sales_Amount__998': 960.84, 'Sales_Representative__998': 'Alexandria Bartlett', 'Customer_Age__998': 40, 'Sales_Region__999': 'West David', 'Discount__999': 10.65, 'Customer_Gender__999': 'Male', 'Product_Category__999': 'Office Supplies', 'Date_of_Sale__999': datetime.datetime(2024, 3, 31, 0, 0), 'Sales_Amount__999': 190.04, 'Sales_Representative__999': 'Colleen Bauer', 'Customer_Age__999': 33}
# 2025-02-16 00:17:24,471 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,472 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/5 (unordered)] {'Sales_Region__0': 'North Wesley', 'Discount__0': 30.23, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Groceries', 'Date_of_Sale__0': datetime.datetime(2024, 2, 16, 0, 0), 'Sales_Amount__0': 879.69, 'Sales_Representative__0': 'Danny Collins', 'Customer_Age__0': 50, 'Sales_Region__1': 'Delgadofurt', 'Discount__1': 3.77, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Movies', 'Date_of_Sale__1': datetime.datetime(2024, 8, 19, 0, 0), 'Sales_Amount__1': 198.04, 'Sales_Representative__1': 'Ashley Mcdowell', 'Customer_Age__1': 54, 'Sales_Region__2': 'Taylorview', 'Discount__2': 25.35, 'Customer_Gender__2': 'Female', 'Product_Category__2': 'Groceries', 'Date_of_Sale__2': datetime.datetime(2024, 5, 26, 0, 0), 'Sales_Amount__2': 602.01, 'Sales_Representative__2': 'Ethan Bass', 'Customer_Age__2': 52, 'Sales_Region__3': 'Angelaborough', 'Discount__3': 32.77, 'Customer_Gender__3': 'Female', 'Product_Category__3': 'Automotive', 'Date_of_Sale__3': datetime.datetime(2024, 7, 9, 0, 0), 'Sales_Amount__3': 931.28, 'Sales_Representative__3': 'Jasmine Beasley', 'Customer_Age__3': 52, 'Sales_Region__4': 'Smithchester', 'Discount__4': 18.55, 'Customer_Gender__4': 'Female', 'Product_Category__4': 'Appliances', 'Date_of_Sale__4': datetime.datetime(2024, 2, 7, 0, 0), 'Sales_Amount__4': 881.48, 'Sales_Representative__4': 'Sheila Reed', 'Customer_Age__4': 61, 'Sales_Region__5': 'Port Steven', 'Discount__5': 6.92, 'Customer_Gender__5': 'Female', 'Product_Category__5': 'Software', 'Date_of_Sale__5': datetime.datetime(2024, 5, 22, 0, 0), 'Sales_Amount__5': 363.59, 'Sales_Representative__5': 'David Moore', 'Customer_Age__5': 44, 'Sales_Region__6': 'Danielmouth', 'Discount__6': 0.0 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Amanda Ortiz', 'Customer_Age__993': 26, 'Sales_Region__994': 'East William', 'Discount__994': 0.89, 'Customer_Gender__994': 'Other', 'Product_Category__994': 'Personal Care', 'Date_of_Sale__994': datetime.datetime(2024, 3, 26, 0, 0), 'Sales_Amount__994': 432.17, 'Sales_Representative__994': 'Adam Smith', 'Customer_Age__994': 52, 'Sales_Region__995': 'Omarhaven', 'Discount__995': 0.0, 'Customer_Gender__995': 'Unknown', 'Product_Category__995': 'Furniture', 'Date_of_Sale__995': datetime.datetime(2024, 7, 14, 0, 0), 'Sales_Amount__995': 550.1708058888889, 'Sales_Representative__995': 'Lori Rodriguez', 'Customer_Age__995': 44, 'Sales_Region__996': 'Christopherbury', 'Discount__996': 12.99, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Outdoor', 'Date_of_Sale__996': datetime.datetime(2024, 8, 5, 0, 0), 'Sales_Amount__996': 250.85, 'Sales_Representative__996': 'Kathryn Cooper', 'Customer_Age__996': 58, 'Sales_Region__997': 'Port Justinchester', 'Discount__997': 36.32, 'Customer_Gender__997': 'Male', 'Product_Category__997': 'Tools', 'Date_of_Sale__997': datetime.datetime(2024, 4, 3, 0, 0), 'Sales_Amount__997': 313.41, 'Sales_Representative__997': 'Joshua Mitchell', 'Customer_Age__997': 65, 'Sales_Region__998': 'Lake Catherineview', 'Discount__998': 46.14, 'Customer_Gender__998': 'Other', 'Product_Category__998': 'Clothing', 'Date_of_Sale__998': datetime.datetime(2024, 3, 14, 0, 0), 'Sales_Amount__998': 102.62, 'Sales_Representative__998': 'Deborah Payne', 'Customer_Age__998': 37, 'Sales_Region__999': 'Bellmouth', 'Discount__999': 31.45, 'Customer_Gender__999': 'Other', 'Product_Category__999': 'Beauty', 'Date_of_Sale__999': datetime.datetime(2024, 5, 24, 0, 0), 'Sales_Amount__999': 544.74, 'Sales_Representative__999': 'Matthew Calhoun', 'Customer_Age__999': 47}
# 2025-02-16 00:17:24,561 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,564 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/5 (unordered)] {'Sales_Region__0': 'North Jeremymouth', 'Discount__0': 26.07, 'Customer_Gender__0': 'Other', 'Product_Category__0': 'Software', 'Date_of_Sale__0': datetime.datetime(2024, 4, 7, 0, 0), 'Sales_Amount__0': 596.55, 'Sales_Representative__0': 'Danielle Bowman', 'Customer_Age__0': 42, 'Sales_Region__1': 'North Douglasshire', 'Discount__1': 14.06, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Jewelry', 'Date_of_Sale__1': datetime.datetime(2024, 5, 18, 0, 0), 'Sales_Amount__1': 556.49, 'Sales_Representative__1': 'April Martinez', 'Customer_Age__1': 65, 'Sales_Region__2': 'Mccarthychester', 'Discount__2': 40.73, 'Customer_Gender__2': 'Female', 'Product_Category__2': 'Tools', 'Date_of_Sale__2': datetime.datetime(2024, 6, 30, 0, 0), 'Sales_Amount__2': 507.27, 'Sales_Representative__2': 'Russell Whitaker', 'Customer_Age__2': 26, 'Sales_Region__3': 'Katieberg', 'Discount__3': 39.19, 'Customer_Gender__3': 'Other', 'Product_Category__3': 'Outdoor', 'Date_of_Sale__3': datetime.datetime(2024, 5, 7, 0, 0), 'Sales_Amount__3': 906.13, 'Sales_Representative__3': 'Jeremy Stein', 'Customer_Age__3': 67, 'Sales_Region__4': 'Markborough', 'Discount__4': 23.57, 'Customer_Gender__4': 'Female', 'Product_Category__4': 'Movies', 'Date_of_Sale__4': datetime.datetime(2024, 8, 8, 0, 0), 'Sales_Amount__4': 404.06, 'Sales_Representative__4': 'Robert Smith', 'Customer_Age__4': 23, 'Sales_Region__5': 'Turnerland', 'Discount__5': 0.0, 'Customer_Gender__5': 'Unknown', 'Product_Category__5': 'Garden', 'Date_of_Sale__5': datetime.datetime(2024, 1, 1, 0, 0), 'Sales_Amount__5': 550.1708058888889, 'Sales_Representative__5': 'Mrs. Rose Bryant', 'Customer_Age__5': 44, 'Sales_Region__6': 'Watsonfort', 'Discount__6': 31.5 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Hannah Jones', 'Customer_Age__993': 68, 'Sales_Region__994': 'East Kristinebury', 'Discount__994': 15.83, 'Customer_Gender__994': 'Male', 'Product_Category__994': 'Sports', 'Date_of_Sale__994': datetime.datetime(2024, 8, 27, 0, 0), 'Sales_Amount__994': 221.08, 'Sales_Representative__994': 'Timothy Mullen', 'Customer_Age__994': 67, 'Sales_Region__995': 'East Nicole', 'Discount__995': 46.87, 'Customer_Gender__995': 'Other', 'Product_Category__995': 'Electronics', 'Date_of_Sale__995': datetime.datetime(2024, 5, 3, 0, 0), 'Sales_Amount__995': 791.25, 'Sales_Representative__995': 'Carol Ramirez', 'Customer_Age__995': 56, 'Sales_Region__996': 'Chrisburgh', 'Discount__996': 5.12, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Electronics', 'Date_of_Sale__996': datetime.datetime(2024, 4, 7, 0, 0), 'Sales_Amount__996': 309.25, 'Sales_Representative__996': 'Sherry Cox', 'Customer_Age__996': 41, 'Sales_Region__997': 'Lake Joshuafurt', 'Discount__997': 41.67, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Software', 'Date_of_Sale__997': datetime.datetime(2024, 8, 18, 0, 0), 'Sales_Amount__997': 900.69, 'Sales_Representative__997': 'Monique Franklin', 'Customer_Age__997': 41, 'Sales_Region__998': 'Meyerton', 'Discount__998': 41.39, 'Customer_Gender__998': 'Female', 'Product_Category__998': 'Toys', 'Date_of_Sale__998': datetime.datetime(2024, 5, 6, 0, 0), 'Sales_Amount__998': 661.41, 'Sales_Representative__998': 'Mary Sims', 'Customer_Age__998': 61, 'Sales_Region__999': 'Waynemouth', 'Discount__999': 18.63, 'Customer_Gender__999': 'Female', 'Product_Category__999': 'Outdoor', 'Date_of_Sale__999': datetime.datetime(2024, 5, 2, 0, 0), 'Sales_Amount__999': 696.74, 'Sales_Representative__999': 'Kelsey Bennett', 'Customer_Age__999': 27}
# 2025-02-16 00:17:24,670 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,672 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/5 (unordered)] {'Sales_Region__0': 'Johnsonport', 'Discount__0': 45.89, 'Customer_Gender__0': 'Other', 'Product_Category__0': 'Personal Care', 'Date_of_Sale__0': datetime.datetime(2024, 6, 12, 0, 0), 'Sales_Amount__0': 752.9, 'Sales_Representative__0': 'Carla Guerra', 'Customer_Age__0': 23, 'Sales_Region__1': 'Wagnertown', 'Discount__1': 19.71, 'Customer_Gender__1': 'Male', 'Product_Category__1': 'Groceries', 'Date_of_Sale__1': datetime.datetime(2024, 3, 4, 0, 0), 'Sales_Amount__1': 690.36, 'Sales_Representative__1': 'Stephen Lin', 'Customer_Age__1': 43, 'Sales_Region__2': 'West Ianview', 'Discount__2': 25.47, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Pet Supplies', 'Date_of_Sale__2': datetime.datetime(2024, 2, 28, 0, 0), 'Sales_Amount__2': 395.0, 'Sales_Representative__2': 'Tina Barry', 'Customer_Age__2': 28, 'Sales_Region__3': 'Port Michael', 'Discount__3': 25.01, 'Customer_Gender__3': 'Other', 'Product_Category__3': 'Automotive', 'Date_of_Sale__3': datetime.datetime(2024, 3, 26, 0, 0), 'Sales_Amount__3': 870.26, 'Sales_Representative__3': 'Michael Maldonado', 'Customer_Age__3': 29, 'Sales_Region__4': 'Angelchester', 'Discount__4': 0.0, 'Customer_Gender__4': 'Unknown', 'Product_Category__4': 'Software', 'Date_of_Sale__4': datetime.datetime(2024, 5, 4, 0, 0), 'Sales_Amount__4': 550.1708058888889, 'Sales_Representative__4': 'Joseph Ryan', 'Customer_Age__4': 44, 'Sales_Region__5': 'Lake Samantha', 'Discount__5': 11.31, 'Customer_Gender__5': 'Female', 'Product_Category__5': 'Tools', 'Date_of_Sale__5': datetime.datetime(2024, 8, 26, 0, 0), 'Sales_Amount__5': 304.11, 'Sales_Representative__5': 'Anthony Sharp', 'Customer_Age__5': 39, 'Sales_Region__6': 'Port Tracy', 'Discount__6': 37.32 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Ricardo Thompson', 'Customer_Age__993': 41, 'Sales_Region__994': 'Port Cassandraview', 'Discount__994': 5.67, 'Customer_Gender__994': 'Male', 'Product_Category__994': 'Home & Kitchen', 'Date_of_Sale__994': datetime.datetime(2024, 8, 21, 0, 0), 'Sales_Amount__994': 187.82, 'Sales_Representative__994': 'Sarah Murphy', 'Customer_Age__994': 42, 'Sales_Region__995': 'New Carolynbury', 'Discount__995': 9.07, 'Customer_Gender__995': 'Female', 'Product_Category__995': 'DIY', 'Date_of_Sale__995': datetime.datetime(2024, 5, 4, 0, 0), 'Sales_Amount__995': 319.41, 'Sales_Representative__995': 'Mr. Jimmy Rivera DDS', 'Customer_Age__995': 27, 'Sales_Region__996': 'South Meganfort', 'Discount__996': 46.53, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Garden', 'Date_of_Sale__996': datetime.datetime(2024, 3, 14, 0, 0), 'Sales_Amount__996': 913.31, 'Sales_Representative__996': 'Sean Buck', 'Customer_Age__996': 28, 'Sales_Region__997': 'Miguelton', 'Discount__997': 0.86, 'Customer_Gender__997': 'Other', 'Product_Category__997': 'Sports', 'Date_of_Sale__997': datetime.datetime(2024, 3, 31, 0, 0), 'Sales_Amount__997': 504.83, 'Sales_Representative__997': 'Linda Reed', 'Customer_Age__997': 22, 'Sales_Region__998': 'Jameshaven', 'Discount__998': 46.26, 'Customer_Gender__998': 'Female', 'Product_Category__998': 'DIY', 'Date_of_Sale__998': datetime.datetime(2024, 1, 30, 0, 0), 'Sales_Amount__998': 701.35, 'Sales_Representative__998': 'Christopher Peterson', 'Customer_Age__998': 41, 'Sales_Region__999': 'Jensenstad', 'Discount__999': 30.04, 'Customer_Gender__999': 'Male', 'Product_Category__999': 'Movies', 'Date_of_Sale__999': datetime.datetime(2024, 8, 6, 0, 0), 'Sales_Amount__999': 887.72, 'Sales_Representative__999': 'David Wang', 'Customer_Age__999': 69}
# 2025-02-16 00:17:24,756 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,757 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/5 (unordered)] {'Sales_Region__0': 'Vaughnborough', 'Discount__0': 12.49, 'Customer_Gender__0': 'Other', 'Product_Category__0': 'Toys', 'Date_of_Sale__0': datetime.datetime(2024, 3, 31, 0, 0), 'Sales_Amount__0': 428.69, 'Sales_Representative__0': 'Cory Rios', 'Customer_Age__0': 27, 'Sales_Region__1': 'Jaimeside', 'Discount__1': 7.69, 'Customer_Gender__1': 'Female', 'Product_Category__1': 'Health', 'Date_of_Sale__1': datetime.datetime(2024, 3, 4, 0, 0), 'Sales_Amount__1': 184.76, 'Sales_Representative__1': 'Kevin Anderson', 'Customer_Age__1': 64, 'Sales_Region__2': 'Joannaborough', 'Discount__2': 13.69, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Beauty', 'Date_of_Sale__2': datetime.datetime(2024, 2, 22, 0, 0), 'Sales_Amount__2': 551.68, 'Sales_Representative__2': 'Lisa Stevens', 'Customer_Age__2': 34, 'Sales_Region__3': 'South Melissa', 'Discount__3': 33.63, 'Customer_Gender__3': 'Other', 'Product_Category__3': 'Groceries', 'Date_of_Sale__3': datetime.datetime(2024, 2, 16, 0, 0), 'Sales_Amount__3': 578.74, 'Sales_Representative__3': 'Donna West', 'Customer_Age__3': 47, 'Sales_Region__4': 'West Jessica', 'Discount__4': 12.16, 'Customer_Gender__4': 'Other', 'Product_Category__4': 'Garden', 'Date_of_Sale__4': datetime.datetime(2024, 3, 18, 0, 0), 'Sales_Amount__4': 664.41, 'Sales_Representative__4': 'Brian Nelson', 'Customer_Age__4': 28, 'Sales_Region__5': 'New Laurastad', 'Discount__5': 5.37, 'Customer_Gender__5': 'Female', 'Product_Category__5': 'Jewelry', 'Date_of_Sale__5': datetime.datetime(2024, 6, 22, 0, 0), 'Sales_Amount__5': 736.08, 'Sales_Representative__5': 'Bradley Garcia', 'Customer_Age__5': 56, 'Sales_Region__6': 'South Stacey', 'Discount__6': 15.42 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Jennifer Rodriguez', 'Customer_Age__993': 57, 'Sales_Region__994': 'Ericastad', 'Discount__994': 46.97, 'Customer_Gender__994': 'Other', 'Product_Category__994': 'Music', 'Date_of_Sale__994': datetime.datetime(2024, 9, 2, 0, 0), 'Sales_Amount__994': 996.33, 'Sales_Representative__994': 'Jessica Mitchell', 'Customer_Age__994': 39, 'Sales_Region__995': 'New Crystal', 'Discount__995': 39.59, 'Customer_Gender__995': 'Male', 'Product_Category__995': 'Toys', 'Date_of_Sale__995': datetime.datetime(2024, 3, 13, 0, 0), 'Sales_Amount__995': 594.27, 'Sales_Representative__995': 'Cynthia Harris', 'Customer_Age__995': 41, 'Sales_Region__996': 'South Bryan', 'Discount__996': 47.07, 'Customer_Gender__996': 'Female', 'Product_Category__996': 'Pet Supplies', 'Date_of_Sale__996': datetime.datetime(2024, 2, 8, 0, 0), 'Sales_Amount__996': 193.89, 'Sales_Representative__996': 'Jonathan Graham', 'Customer_Age__996': 66, 'Sales_Region__997': 'Roseborough', 'Discount__997': 8.23, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Groceries', 'Date_of_Sale__997': datetime.datetime(2024, 8, 1, 0, 0), 'Sales_Amount__997': 717.17, 'Sales_Representative__997': 'Jose Johnston', 'Customer_Age__997': 24, 'Sales_Region__998': 'Arnoldberg', 'Discount__998': 25.78, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Books', 'Date_of_Sale__998': datetime.datetime(2024, 5, 26, 0, 0), 'Sales_Amount__998': 715.92, 'Sales_Representative__998': 'Gregory Johnson', 'Customer_Age__998': 37, 'Sales_Region__999': 'Jameshaven', 'Discount__999': 47.36, 'Customer_Gender__999': 'Other', 'Product_Category__999': 'Automotive', 'Date_of_Sale__999': datetime.datetime(2024, 3, 3, 0, 0), 'Sales_Amount__999': 714.22, 'Sales_Representative__999': 'Brianna Harris', 'Customer_Age__999': 36}
# 2025-02-16 00:17:24,909 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:24,912 INFO sqlalchemy.engine.Engine [cached since 1.175s ago (insertmanyvalues) 1/5 (unordered)] {'Sales_Region__0': 'West Mark', 'Discount__0': 3.11, 'Customer_Gender__0': 'Male', 'Product_Category__0': 'Sports', 'Date_of_Sale__0': datetime.datetime(2024, 1, 20, 0, 0), 'Sales_Amount__0': 273.69, 'Sales_Representative__0': 'Kelly Chen', 'Customer_Age__0': 48, 'Sales_Region__1': 'West Dennis', 'Discount__1': 13.64, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Pet Supplies', 'Date_of_Sale__1': datetime.datetime(2024, 8, 8, 0, 0), 'Sales_Amount__1': 123.87, 'Sales_Representative__1': 'Kristin Travis', 'Customer_Age__1': 19, 'Sales_Region__2': 'East Alexistown', 'Discount__2': 5.12, 'Customer_Gender__2': 'Other', 'Product_Category__2': 'Baby Products', 'Date_of_Sale__2': datetime.datetime(2024, 3, 2, 0, 0), 'Sales_Amount__2': 345.52, 'Sales_Representative__2': 'John Peck', 'Customer_Age__2': 55, 'Sales_Region__3': 'Phillipsborough', 'Discount__3': 0.0, 'Customer_Gender__3': 'Unknown', 'Product_Category__3': 'Jewelry', 'Date_of_Sale__3': datetime.datetime(2024, 1, 10, 0, 0), 'Sales_Amount__3': 550.1708058888889, 'Sales_Representative__3': 'Erica Wong', 'Customer_Age__3': 44, 'Sales_Region__4': 'South Jade', 'Discount__4': 0.0, 'Customer_Gender__4': 'Unknown', 'Product_Category__4': 'DIY', 'Date_of_Sale__4': datetime.datetime(2024, 5, 4, 0, 0), 'Sales_Amount__4': 550.1708058888889, 'Sales_Representative__4': 'Matthew Johnson', 'Customer_Age__4': 44, 'Sales_Region__5': 'Millerport', 'Discount__5': 15.73, 'Customer_Gender__5': 'Other', 'Product_Category__5': 'Appliances', 'Date_of_Sale__5': datetime.datetime(2024, 3, 28, 0, 0), 'Sales_Amount__5': 921.38, 'Sales_Representative__5': 'Yvette Roberts', 'Customer_Age__5': 21, 'Sales_Region__6': 'Lake James', 'Discount__6': 0.0 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Ricky Lee', 'Customer_Age__993': 44, 'Sales_Region__994': 'Joditown', 'Discount__994': 11.16, 'Customer_Gender__994': 'Female', 'Product_Category__994': 'Outdoor', 'Date_of_Sale__994': datetime.datetime(2024, 4, 6, 0, 0), 'Sales_Amount__994': 784.73, 'Sales_Representative__994': 'Johnny Reeves', 'Customer_Age__994': 41, 'Sales_Region__995': 'Randyfort', 'Discount__995': 26.61, 'Customer_Gender__995': 'Female', 'Product_Category__995': 'Groceries', 'Date_of_Sale__995': datetime.datetime(2024, 8, 9, 0, 0), 'Sales_Amount__995': 832.81, 'Sales_Representative__995': 'Michael Rose II', 'Customer_Age__995': 64, 'Sales_Region__996': 'West David', 'Discount__996': 17.71, 'Customer_Gender__996': 'Male', 'Product_Category__996': 'Garden', 'Date_of_Sale__996': datetime.datetime(2024, 7, 4, 0, 0), 'Sales_Amount__996': 150.17, 'Sales_Representative__996': 'Lauren Tucker', 'Customer_Age__996': 59, 'Sales_Region__997': 'Christopherton', 'Discount__997': 29.15, 'Customer_Gender__997': 'Other', 'Product_Category__997': 'Sports', 'Date_of_Sale__997': datetime.datetime(2024, 2, 1, 0, 0), 'Sales_Amount__997': 445.0, 'Sales_Representative__997': 'Jacob Howe', 'Customer_Age__997': 27, 'Sales_Region__998': 'East Edwardtown', 'Discount__998': 34.34, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Sports', 'Date_of_Sale__998': datetime.datetime(2024, 4, 10, 0, 0), 'Sales_Amount__998': 169.99, 'Sales_Representative__998': 'Nancy Ray', 'Customer_Age__998': 24, 'Sales_Region__999': 'Diazview', 'Discount__999': 33.11, 'Customer_Gender__999': 'Male', 'Product_Category__999': 'Sports', 'Date_of_Sale__999': datetime.datetime(2024, 6, 29, 0, 0), 'Sales_Amount__999': 883.8, 'Sales_Representative__999': 'Troy Bond', 'Customer_Age__999': 35}
# 2025-02-16 00:17:25,019 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# ...
# 2025-02-16 00:17:35,581 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:35,582 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/5 (unordered)] {'Sales_Region__0': 'Johnmouth', 'Discount__0': 19.14, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Furniture', 'Date_of_Sale__0': datetime.datetime(2024, 5, 9, 0, 0), 'Sales_Amount__0': 928.8, 'Sales_Representative__0': 'Cindy Watts', 'Customer_Age__0': 30, 'Sales_Region__1': 'Prestonside', 'Discount__1': 10.75, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Baby Products', 'Date_of_Sale__1': datetime.datetime(2024, 1, 21, 0, 0), 'Sales_Amount__1': 105.25, 'Sales_Representative__1': 'Christina Ramos', 'Customer_Age__1': 50, 'Sales_Region__2': 'Colonbury', 'Discount__2': 35.28, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Groceries', 'Date_of_Sale__2': datetime.datetime(2024, 4, 20, 0, 0), 'Sales_Amount__2': 985.18, 'Sales_Representative__2': 'Matthew Mills', 'Customer_Age__2': 48, 'Sales_Region__3': 'North Taylor', 'Discount__3': 45.75, 'Customer_Gender__3': 'Male', 'Product_Category__3': 'Furniture', 'Date_of_Sale__3': datetime.datetime(2024, 5, 20, 0, 0), 'Sales_Amount__3': 552.07, 'Sales_Representative__3': 'Summer Joyce', 'Customer_Age__3': 21, 'Sales_Region__4': 'Timothyside', 'Discount__4': 28.99, 'Customer_Gender__4': 'Male', 'Product_Category__4': 'Movies', 'Date_of_Sale__4': datetime.datetime(2024, 3, 20, 0, 0), 'Sales_Amount__4': 766.45, 'Sales_Representative__4': 'Victoria Potts', 'Customer_Age__4': 64, 'Sales_Region__5': 'West Elizabethbury', 'Discount__5': 12.98, 'Customer_Gender__5': 'Male', 'Product_Category__5': 'Appliances', 'Date_of_Sale__5': datetime.datetime(2024, 5, 19, 0, 0), 'Sales_Amount__5': 525.27, 'Sales_Representative__5': 'Rebecca Lewis', 'Customer_Age__5': 26, 'Sales_Region__6': 'Martinezhaven', 'Discount__6': 0.0 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Neil Cummings', 'Customer_Age__993': 58, 'Sales_Region__994': 'New Margaret', 'Discount__994': 0.0, 'Customer_Gender__994': 'Unknown', 'Product_Category__994': 'Appliances', 'Date_of_Sale__994': datetime.datetime(2024, 3, 16, 0, 0), 'Sales_Amount__994': 550.1708058888889, 'Sales_Representative__994': 'Daniel Zuniga', 'Customer_Age__994': 44, 'Sales_Region__995': 'Lake Darrellshire', 'Discount__995': 10.4, 'Customer_Gender__995': 'Female', 'Product_Category__995': 'Automotive', 'Date_of_Sale__995': datetime.datetime(2024, 1, 22, 0, 0), 'Sales_Amount__995': 744.74, 'Sales_Representative__995': 'Wendy Holmes', 'Customer_Age__995': 52, 'Sales_Region__996': 'Pattonborough', 'Discount__996': 9.01, 'Customer_Gender__996': 'Other', 'Product_Category__996': 'Automotive', 'Date_of_Sale__996': datetime.datetime(2024, 6, 21, 0, 0), 'Sales_Amount__996': 130.47, 'Sales_Representative__996': 'Monica Lambert', 'Customer_Age__996': 44, 'Sales_Region__997': 'East John', 'Discount__997': 40.56, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Personal Care', 'Date_of_Sale__997': datetime.datetime(2024, 3, 27, 0, 0), 'Sales_Amount__997': 747.54, 'Sales_Representative__997': 'Stephanie Horton', 'Customer_Age__997': 55, 'Sales_Region__998': 'Port Dawn', 'Discount__998': 4.62, 'Customer_Gender__998': 'Female', 'Product_Category__998': 'Pet Supplies', 'Date_of_Sale__998': datetime.datetime(2024, 9, 3, 0, 0), 'Sales_Amount__998': 243.53, 'Sales_Representative__998': 'Anna Montgomery', 'Customer_Age__998': 56, 'Sales_Region__999': 'South Shelleyton', 'Discount__999': 46.3, 'Customer_Gender__999': 'Other', 'Product_Category__999': 'Books', 'Date_of_Sale__999': datetime.datetime(2024, 7, 18, 0, 0), 'Sales_Amount__999': 141.44, 'Sales_Representative__999': 'Jennifer Francis', 'Customer_Age__999': 18}
# 2025-02-16 00:17:35,682 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:35,684 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/5 (unordered)] {'Sales_Region__0': 'Simmonsport', 'Discount__0': 25.13, 'Customer_Gender__0': 'Female', 'Product_Category__0': 'Pet Supplies', 'Date_of_Sale__0': datetime.datetime(2024, 1, 30, 0, 0), 'Sales_Amount__0': 970.91, 'Sales_Representative__0': 'Tyler Banks', 'Customer_Age__0': 66, 'Sales_Region__1': 'Port Sierraport', 'Discount__1': 47.13, 'Customer_Gender__1': 'Other', 'Product_Category__1': 'Software', 'Date_of_Sale__1': datetime.datetime(2024, 9, 5, 0, 0), 'Sales_Amount__1': 272.72, 'Sales_Representative__1': 'David Pennington', 'Customer_Age__1': 32, 'Sales_Region__2': 'Wayneshire', 'Discount__2': 14.98, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Beauty', 'Date_of_Sale__2': datetime.datetime(2024, 1, 13, 0, 0), 'Sales_Amount__2': 723.76, 'Sales_Representative__2': 'Mrs. Karen Williams', 'Customer_Age__2': 23, 'Sales_Region__3': 'Port Brittanychester', 'Discount__3': 32.69, 'Customer_Gender__3': 'Male', 'Product_Category__3': 'Outdoor', 'Date_of_Sale__3': datetime.datetime(2024, 9, 9, 0, 0), 'Sales_Amount__3': 541.55, 'Sales_Representative__3': 'David Boyd', 'Customer_Age__3': 50, 'Sales_Region__4': 'Port Bonnieberg', 'Discount__4': 5.99, 'Customer_Gender__4': 'Male', 'Product_Category__4': 'Office Supplies', 'Date_of_Sale__4': datetime.datetime(2024, 8, 15, 0, 0), 'Sales_Amount__4': 850.47, 'Sales_Representative__4': 'William Mullins', 'Customer_Age__4': 50, 'Sales_Region__5': 'East Michaelmouth', 'Discount__5': 19.46, 'Customer_Gender__5': 'Male', 'Product_Category__5': 'Toys', 'Date_of_Sale__5': datetime.datetime(2024, 8, 12, 0, 0), 'Sales_Amount__5': 872.03, 'Sales_Representative__5': 'Rhonda Stuart', 'Customer_Age__5': 18, 'Sales_Region__6': 'Port Karenberg', 'Discount__6': 40.7 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Jeremy Weber', 'Customer_Age__993': 27, 'Sales_Region__994': 'New Brianna', 'Discount__994': 3.4, 'Customer_Gender__994': 'Female', 'Product_Category__994': 'Automotive', 'Date_of_Sale__994': datetime.datetime(2024, 9, 4, 0, 0), 'Sales_Amount__994': 441.39, 'Sales_Representative__994': 'Megan Richardson', 'Customer_Age__994': 50, 'Sales_Region__995': 'South Dorothy', 'Discount__995': 22.13, 'Customer_Gender__995': 'Female', 'Product_Category__995': 'Jewelry', 'Date_of_Sale__995': datetime.datetime(2024, 6, 24, 0, 0), 'Sales_Amount__995': 358.72, 'Sales_Representative__995': 'Courtney Davis', 'Customer_Age__995': 38, 'Sales_Region__996': 'West Suzanne', 'Discount__996': 18.56, 'Customer_Gender__996': 'Other', 'Product_Category__996': 'Automotive', 'Date_of_Sale__996': datetime.datetime(2024, 7, 8, 0, 0), 'Sales_Amount__996': 220.73, 'Sales_Representative__996': 'Scott Garcia', 'Customer_Age__996': 39, 'Sales_Region__997': 'Ryanfort', 'Discount__997': 5.02, 'Customer_Gender__997': 'Female', 'Product_Category__997': 'Groceries', 'Date_of_Sale__997': datetime.datetime(2024, 4, 11, 0, 0), 'Sales_Amount__997': 624.48, 'Sales_Representative__997': 'Nathan Brock', 'Customer_Age__997': 46, 'Sales_Region__998': 'New Kimberly', 'Discount__998': 0.0, 'Customer_Gender__998': 'Unknown', 'Product_Category__998': 'Software', 'Date_of_Sale__998': datetime.datetime(2024, 7, 1, 0, 0), 'Sales_Amount__998': 550.1708058888889, 'Sales_Representative__998': 'Robert Rich', 'Customer_Age__998': 44, 'Sales_Region__999': 'Richardhaven', 'Discount__999': 8.19, 'Customer_Gender__999': 'Other', 'Product_Category__999': 'Furniture', 'Date_of_Sale__999': datetime.datetime(2024, 8, 13, 0, 0), 'Sales_Amount__999': 964.66, 'Sales_Representative__999': 'Miss Erika Reyes DVM', 'Customer_Age__999': 57}
# 2025-02-16 00:17:35,772 INFO sqlalchemy.engine.Engine INSERT INTO ventes_data ("Product_Category", "Sales_Amount", "Discount", "Sales_Region", "Date_of_Sale", "Customer_Age", "Customer_Gender", "Sales_Representative") VALUES (%(Product_Category__0)s, %(Sales_Amount__0)s, %(Discount__0)s, %(Sales_Region_ ... 195939 characters truncated ... Date_of_Sale__999)s, %(Customer_Age__999)s, %(Customer_Gender__999)s, %(Sales_Representative__999)s)
# 2025-02-16 00:17:35,773 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/5 (unordered)] {'Sales_Region__0': 'North Whitneymouth', 'Discount__0': 40.82, 'Customer_Gender__0': 'Male', 'Product_Category__0': 'Personal Care', 'Date_of_Sale__0': datetime.datetime(2024, 2, 23, 0, 0), 'Sales_Amount__0': 602.89, 'Sales_Representative__0': 'Brian Baker', 'Customer_Age__0': 25, 'Sales_Region__1': 'Taylortown', 'Discount__1': 0.0, 'Customer_Gender__1': 'Unknown', 'Product_Category__1': 'Movies', 'Date_of_Sale__1': datetime.datetime(2024, 2, 5, 0, 0), 'Sales_Amount__1': 550.1708058888889, 'Sales_Representative__1': 'Julie Bell', 'Customer_Age__1': 44, 'Sales_Region__2': 'Shawburgh', 'Discount__2': 29.1, 'Customer_Gender__2': 'Male', 'Product_Category__2': 'Electronics', 'Date_of_Sale__2': datetime.datetime(2024, 5, 4, 0, 0), 'Sales_Amount__2': 881.77, 'Sales_Representative__2': 'Elizabeth Robinson', 'Customer_Age__2': 23, 'Sales_Region__3': 'Wilkinsberg', 'Discount__3': 5.83, 'Customer_Gender__3': 'Female', 'Product_Category__3': 'Tools', 'Date_of_Sale__3': datetime.datetime(2024, 3, 22, 0, 0), 'Sales_Amount__3': 398.34, 'Sales_Representative__3': 'Nathaniel Rodriguez', 'Customer_Age__3': 40, 'Sales_Region__4': 'Lake Nichole', 'Discount__4': 48.9, 'Customer_Gender__4': 'Male', 'Product_Category__4': 'Groceries', 'Date_of_Sale__4': datetime.datetime(2024, 8, 3, 0, 0), 'Sales_Amount__4': 513.11, 'Sales_Representative__4': 'Jasmin Alvarado', 'Customer_Age__4': 52, 'Sales_Region__5': 'Port Michael', 'Discount__5': 0.78, 'Customer_Gender__5': 'Other', 'Product_Category__5': 'Jewelry', 'Date_of_Sale__5': datetime.datetime(2024, 2, 8, 0, 0), 'Sales_Amount__5': 701.04, 'Sales_Representative__5': 'Nicole Randall', 'Customer_Age__5': 40, 'Sales_Region__6': 'Wallacemouth', 'Discount__6': 32.39 ... 7900 parameters truncated ... 'Sales_Representative__993': 'Lisa Rivas', 'Customer_Age__993': 40, 'Sales_Region__994': 'South Robert', 'Discount__994': 5.17, 'Customer_Gender__994': 'Male', 'Product_Category__994': 'Groceries', 'Date_of_Sale__994': datetime.datetime(2024, 4, 1, 0, 0), 'Sales_Amount__994': 854.98, 'Sales_Representative__994': 'Jeffrey Pope', 'Customer_Age__994': 47, 'Sales_Region__995': 'Sandramouth', 'Discount__995': 15.83, 'Customer_Gender__995': 'Male', 'Product_Category__995': 'Automotive', 'Date_of_Sale__995': datetime.datetime(2024, 3, 25, 0, 0), 'Sales_Amount__995': 871.22, 'Sales_Representative__995': 'Wendy Jacobs', 'Customer_Age__995': 67, 'Sales_Region__996': 'Deannastad', 'Discount__996': 36.49, 'Customer_Gender__996': 'Female', 'Product_Category__996': 'Appliances', 'Date_of_Sale__996': datetime.datetime(2024, 1, 7, 0, 0), 'Sales_Amount__996': 620.85, 'Sales_Representative__996': 'Kevin Bradshaw', 'Customer_Age__996': 51, 'Sales_Region__997': 'Lake Brookeshire', 'Discount__997': 29.01, 'Customer_Gender__997': 'Other', 'Product_Category__997': 'Sports', 'Date_of_Sale__997': datetime.datetime(2024, 5, 3, 0, 0), 'Sales_Amount__997': 479.04, 'Sales_Representative__997': 'Isaac Harrell', 'Customer_Age__997': 56, 'Sales_Region__998': 'Port Raymond', 'Discount__998': 9.6, 'Customer_Gender__998': 'Male', 'Product_Category__998': 'Office Supplies', 'Date_of_Sale__998': datetime.datetime(2024, 1, 28, 0, 0), 'Sales_Amount__998': 419.56, 'Sales_Representative__998': 'Austin Brown', 'Customer_Age__998': 43, 'Sales_Region__999': 'North Diane', 'Discount__999': 0.0, 'Customer_Gender__999': 'Unknown', 'Product_Category__999': 'DIY', 'Date_of_Sale__999': datetime.datetime(2024, 6, 3, 0, 0), 'Sales_Amount__999': 550.1708058888889, 'Sales_Representative__999': 'John Jones', 'Customer_Age__999': 44}
#
# ✅ 100000 lignes insérées avec succès dans PostgreSQL !
# 2025-02-16 00:17:35,872 INFO sqlalchemy.engine.Engine ROLLBACK using DBAPI connection.rollback(), DBAPI should ignore due to autocommit mode
